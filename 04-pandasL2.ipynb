# %% [markdown]
# # Day 9

# %%
import pandas as pd

# %%
df = pd.read_csv("./helperFiles/Books.csv")

# %% [markdown]
# No. of observation

# %%
df.count()
# Out:
# title             2049
# author            2049
# pages             2049
# genre             2049
# description       2049
# published_date    2049
# publisher         2049
# language          2049
# average_rating    2049
# ratings_count     2049
# thumbnail         2049
# dtype: int64

# %% [markdown]
# First 5 row

# %%
df.head()
# Out:
#                                                title  \
# 0                           Fictional Points of View
# 1             Science Fiction and Fantasy Literature
# 2               Library of Congress Subject Headings
# 3               Library of Congress Subject Headings
# 4  Fictional Space in the Modernist and Post-mode...
#
#                                               author pages  \
# 0                                     Peter Lamarque   252
# 1     R. Reginald, Douglas Menville, Mary A. Burgess   802
# 2  Library of Congress. Cataloging Policy and Sup...  1662
# 3                                Library of Congress  1512
# 4                               Carl Darryl Malmgren   248
#
#                                    genre  \
# 0                     Literary Criticism
# 1                              Reference
# 2  Subject headings, Library of Congress
# 3  Subject headings, Library of Congress
# 4                                Fiction
#
# ...

# %% [markdown]
# Last 10 rows

# %%
df.tail(10)
# Out:
#                         title                        author pages  \
# 2039     The Millionaire Mind             Thomas J. Stanley   416
# 2040        The Wealth Choice                 Dennis Kimbro   304
# 2041         The Behavior Gap                 Carl Richards   208
# 2042  The Million Dollar Club         Kimberly Seals-Allers   256
# 2043         The Art of Money                  Bari Tessler   304
# 2044           The Index Card  Helaine Olen, Harold Pollack   256
# 2045       The Road to Wealth                    Suze Orman   608
# 2046   The Success Principles                 Jack Canfield   512
# 2047   The Courage to Be Rich                    Suze Orman   448
# 2048         The Money Manual                  Tonya Rapley   256
#
#                  genre                                        description  \
# 2039  Personal Finance  Explores the mindset and habits of millionaire...
# 2040         Self-Help  Insights from successful African Americans on ...
# ...

# %% [markdown]
# Datatypes of every variable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2049 entries, 0 to 2048
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2049 non-null   object
#  1   author          2049 non-null   object
#  2   pages           2049 non-null   object
#  3   genre           2049 non-null   object
#  4   description     2049 non-null   object
#  5   published_date  2049 non-null   object
#  6   publisher       2049 non-null   object
#  7   language        2049 non-null   object
#  8   average_rating  2049 non-null   object
#  9   ratings_count   2049 non-null   int64
#  10  thumbnail       2049 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 176.2+ KB

# %%
df.describe()
# Out:
#         ratings_count
# count     2049.000000
# mean      3704.258663
# std      40015.992383
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max    1000000.000000

# %%
duplicates = df[df.duplicated()].count()
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object', 'category']).columns
len(duplicates), len(num_cols), len(cat_cols)
# Out:
# (11, 1, 10)

# %%
if df.shape[0] >700:
    new_df = df.iloc[::2,:]
else:
    new_df = df.iloc[:,::2]
new_df
# Out:
#                                                   title  \
# 0                              Fictional Points of View
# 2                  Library of Congress Subject Headings
# 4     Fictional Space in the Modernist and Post-mode...
# 6     Fictional Practice: Magic, Narration, and the ...
# 8       Essential Skills - Reading and Writing, Grade 1
# ...                                                 ...
# 2040                                  The Wealth Choice
# 2042                            The Million Dollar Club
# 2044                                     The Index Card
# 2046                             The Success Principles
# 2048                                   The Money Manual
#
#                                                  author pages  \
# 0                                        Peter Lamarque   252
# 2     Library of Congress. Cataloging Policy and Sup...  1662
# 4                                  Carl Darryl Malmgren   248
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# author            0
# pages             0
# genre             0
# description       0
# published_date    0
# publisher         0
# language          0
# average_rating    0
# ratings_count     0
# thumbnail         0
# dtype: int64

# %%
for col in df.columns:
    print(f"\nValues in column: {col}")
    print(df[col].value_counts())
# Out:
# Values in column: title
# title
# Popular Science                              31
# Twilight                                     12
# Library of Congress Subject Headings         11
# Jane Eyre                                     8
# Competition Science Vision                    7
#                                              ..
# Money Master the Game                         1
# The Automatic Millionaire                     1
# The Little Book of Common Sense Investing     1
# Mindset: The New Psychology of Success        1
# The Financial Diet                            1
# Name: count, Length: 1900, dtype: int64
#
# Values in column: author
# author
# Unknown Author                                    255
# Stephen King                                       22
# Agatha Christie                                    21
# Dan Brown                                          20
# Charles Dickens                                    17
#                                                  ...
# ...

# %%
df.rename(columns={'author':'akshat'},inplace=True)
df.head()
# Out:
#                                                title  \
# 0                           Fictional Points of View
# 1             Science Fiction and Fantasy Literature
# 2               Library of Congress Subject Headings
# 3               Library of Congress Subject Headings
# 4  Fictional Space in the Modernist and Post-mode...
#
#                                               akshat pages  \
# 0                                     Peter Lamarque   252
# 1     R. Reginald, Douglas Menville, Mary A. Burgess   802
# 2  Library of Congress. Cataloging Policy and Sup...  1662
# 3                                Library of Congress  1512
# 4                               Carl Darryl Malmgren   248
#
#                                    genre  \
# 0                     Literary Criticism
# 1                              Reference
# 2  Subject headings, Library of Congress
# 3  Subject headings, Library of Congress
# 4                                Fiction
#
# ...

# %% [markdown]
# # Day 10

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1 = df[["Name", "Sex", "Age"]][:5]
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2 = df[["Name", "Sex", "Age"]][5:10]
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1+df2
# Out:
#   Name  Sex  Age
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  NaN  NaN
# 4  NaN  NaN  NaN
# 5  NaN  NaN  NaN
# 6  NaN  NaN  NaN
# 7  NaN  NaN  NaN
# 8  NaN  NaN  NaN
# 9  NaN  NaN  NaN

# %%
pd.concat([df1, df2],axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1, df2], axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1 = pd.DataFrame({'key1':[1,2,3,4,5],'key2':[3,4,5,6,7],'key3':[6,7,8,9,1]})
df1
# Out:
#    key1  key2  key3
# 0     1     3     6
# 1     2     4     7
# 2     3     5     8
# 3     4     6     9
# 4     5     7     1

# %%
df2 = pd.DataFrame({'key1':[1,20,3,4,5],'key4':[3,4,5,60,7],'key5':[6,7,98,9,10]})
df2
# Out:
#    key1  key4  key5
# 0     1     3     6
# 1    20     4     7
# 2     3     5    98
# 3     4    60     9
# 4     5     7    10

# %%
pd.merge(df1,df2,how='inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     6     3     6
# 1     3     5     8     5    98
# 2     4     6     9    60     9
# 3     5     7     1     7    10

# %%
pd.merge(df1,df2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     6   3.0   6.0
# 1     2     4     7   NaN   NaN
# 2     3     5     8   5.0  98.0
# 3     4     6     9  60.0   9.0
# 4     5     7     1   7.0  10.0

# %%
pd.merge(df1,df2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   6.0     3     6
# 1    20   NaN   NaN     4     7
# 2     3   5.0   8.0     5    98
# 3     4   6.0   9.0    60     9
# 4     5   7.0   1.0     7    10

# %%
pd.merge(df1,df2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   6.0   3.0   6.0
# 1     2   4.0   7.0   NaN   NaN
# 2     3   5.0   8.0   5.0  98.0
# 3     4   6.0   9.0  60.0   9.0
# 4     5   7.0   1.0   7.0  10.0
# 5    20   NaN   NaN   4.0   7.0

# %%
pd.merge(df1,df2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     3     6       1     3     6
# 1        1     3     6      20     4     7
# 2        1     3     6       3     5    98
# 3        1     3     6       4    60     9
# 4        1     3     6       5     7    10
# 5        2     4     7       1     3     6
# 6        2     4     7      20     4     7
# 7        2     4     7       3     5    98
# 8        2     4     7       4    60     9
# 9        2     4     7       5     7    10
# 10       3     5     8       1     3     6
# 11       3     5     8      20     4     7
# 12       3     5     8       3     5    98
# 13       3     5     8       4    60     9
# 14       3     5     8       5     7    10
# 15       4     6     9       1     3     6
# 16       4     6     9      20     4     7
# 17       4     6     9       3     5    98
# 18       4     6     9       4    60     9
# 19       4     6     9       5     7    10
# 20       5     7     1       1     3     6
# ...

# %%
pd.merge(df1,df2,how='left',left_on='key2',right_on='key4')
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     3     6     1.0   3.0   6.0
# 1       2     4     7    20.0   4.0   7.0
# 2       3     5     8     3.0   5.0  98.0
# 3       4     6     9     NaN   NaN   NaN
# 4       5     7     1     5.0   7.0  10.0

# %%
df1 = pd.DataFrame({'key1':[1,2,3,4,5],'key2':[4,5,6,7,8],'key3':[3,4,5,6,7]},index=['a','b','c','d','e'])
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     3     6     5
# d     4     7     6
# e     5     8     7

# %%
df2 = pd.DataFrame({'key6':[1,2,33,4,5],'key5':[34,5,6,7,8],'key4':[3,4,5,64,7]},index=['g','b','c','e','j'])
df2
# Out:
#    key6  key5  key4
# g     1    34     3
# b     2     5     4
# c    33     6     5
# e     4     7    64
# j     5     8     7

# %%
df1.join(df2, how='inner')
# Out:
#    key1  key2  key3  key6  key5  key4
# b     2     5     4     2     5     4
# c     3     6     5    33     6     5
# e     5     8     7     4     7    64

# %%
df1.join(df2, how='left')
# Out:
#    key1  key2  key3  key6  key5  key4
# a     1     4     3   NaN   NaN   NaN
# b     2     5     4   2.0   5.0   4.0
# c     3     6     5  33.0   6.0   5.0
# d     4     7     6   NaN   NaN   NaN
# e     5     8     7   4.0   7.0  64.0

# %%
df1.join(df2, how='right')
# Out:
#    key1  key2  key3  key6  key5  key4
# g   NaN   NaN   NaN     1    34     3
# b   2.0   5.0   4.0     2     5     4
# c   3.0   6.0   5.0    33     6     5
# e   5.0   8.0   7.0     4     7    64
# j   NaN   NaN   NaN     5     8     7

# %%
df1.join(df2, how='cross')
# Out:
#     key1  key2  key3  key6  key5  key4
# 0      1     4     3     1    34     3
# 1      1     4     3     2     5     4
# 2      1     4     3    33     6     5
# 3      1     4     3     4     7    64
# 4      1     4     3     5     8     7
# 5      2     5     4     1    34     3
# 6      2     5     4     2     5     4
# 7      2     5     4    33     6     5
# 8      2     5     4     4     7    64
# 9      2     5     4     5     8     7
# 10     3     6     5     1    34     3
# 11     3     6     5     2     5     4
# 12     3     6     5    33     6     5
# 13     3     6     5     4     7    64
# 14     3     6     5     5     8     7
# 15     4     7     6     1    34     3
# 16     4     7     6     2     5     4
# 17     4     7     6    33     6     5
# 18     4     7     6     4     7    64
# 19     4     7     6     5     8     7
# 20     5     8     7     1    34     3
# 21     5     8     7     2     5     4
# 22     5     8     7    33     6     5
# ...

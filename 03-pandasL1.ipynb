# %% [markdown]
# # Day-06

# %%
import pandas as pd

# %%
pd.read_csv("./helperFiles/services.csv")
# Out:
#                               Service  Custodian  \
# 0                     Adapt a vehicle  Not known
# 1                       Adopt a child  Not known
# 2                Apply for a passport  Not known
# 3              Be re-setted in the UK  Not known
# 4            Become a British citizen  Not known
# ..                                ...        ...
# 143            Use accessible parking  Not known
# 144                      Visit the UK  Not known
# 145                         Volunteer  Not known
# 146  What to do when someone has died  Not known
# 147                       Work abroad  Not known
#
#                                           Delivered by  \
# 0                                            DVLA DVSA
# 1    Courts-Tribunals-Service DfE Passport-Office l...
# 2                                      Passport-Office
# 3                         Home-Office local-government
# 4                                          Home-Office
# ...

# %%
df = pd.read_csv("./helperFiles/services.csv",header=None)
df
# Out:
#                                     0          1  \
# 0                             Service  Custodian
# 1                     Adapt a vehicle  Not known
# 2                       Adopt a child  Not known
# 3                Apply for a passport  Not known
# 4              Be re-setted in the UK  Not known
# ..                                ...        ...
# 144            Use accessible parking  Not known
# 145                      Visit the UK  Not known
# 146                         Volunteer  Not known
# 147  What to do when someone has died  Not known
# 148                       Work abroad  Not known
#
#                                                      2  \
# 0                                         Delivered by
# 1                                            DVLA DVSA
# 2    Courts-Tribunals-Service DfE Passport-Office l...
# 3                                      Passport-Office
# 4                         Home-Office local-government
# ...

# %%
df = pd.read_csv("./helperFiles/services.csv",skiprows=2)
df
# Out:
#                         Adopt a child  Not known  \
# 0                Apply for a passport  Not known
# 1              Be re-setted in the UK  Not known
# 2            Become a British citizen  Not known
# 3                Become a childminder  Not known
# 4               Become a scrap dealer  Not known
# ..                                ...        ...
# 141            Use accessible parking  Not known
# 142                      Visit the UK  Not known
# 143                         Volunteer  Not known
# 144  What to do when someone has died  Not known
# 145                       Work abroad  Not known
#
#     Courts-Tribunals-Service DfE Passport-Office local-government  \
# 0                                      Passport-Office
# 1                         Home-Office local-government
# 2                                          Home-Office
# 3             Home-Office HMRC local-government Ofsted
# 4                                     local-government
# ...

# %%
df = pd.read_csv("./helperFiles/services.csv")
df
# Out:
#                               Service  Custodian  \
# 0                     Adapt a vehicle  Not known
# 1                       Adopt a child  Not known
# 2                Apply for a passport  Not known
# 3              Be re-setted in the UK  Not known
# 4            Become a British citizen  Not known
# ..                                ...        ...
# 143            Use accessible parking  Not known
# 144                      Visit the UK  Not known
# 145                         Volunteer  Not known
# 146  What to do when someone has died  Not known
# 147                       Work abroad  Not known
#
#                                           Delivered by  \
# 0                                            DVLA DVSA
# 1    Courts-Tribunals-Service DfE Passport-Office l...
# 2                                      Passport-Office
# 3                         Home-Office local-government
# 4                                          Home-Office
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Service']
# Out:
# 0                       Adapt a vehicle
# 1                         Adopt a child
# 2                  Apply for a passport
# 3                Be re-setted in the UK
# 4              Become a British citizen
#                      ...
# 143              Use accessible parking
# 144                        Visit the UK
# 145                           Volunteer
# 146    What to do when someone has died
# 147                         Work abroad
# Name: Service, Length: 148, dtype: object

# %%
type(df['Service'])
# Out:
# pandas.core.series.Series

# %%
l = [1,2,3,4]
s = pd.Series(l)
s, type(s)
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  dtype: int64,
#  pandas.core.series.Series)

# %%
d = pd.Series([100,1000,10000,100000], index=["Hundred","Thousand","Ten thousand","Lakh"])
d
# Out:
# Hundred            100
# Thousand          1000
# Ten thousand     10000
# Lakh            100000
# dtype: int64

# %%
d['thousand'] = '1k'
d
# Out:
# Hundred            100
# Thousand          1000
# Ten thousand     10000
# Lakh            100000
# thousand            1k
# dtype: object

# %%
d.reset_index(drop=True, inplace=True)

# %%
d[0:2]
# Out:
# 0     100
# 1    1000
# dtype: object

# %%
df = pd.read_csv("./helperFiles/services.csv")

# %%
df.shape
# Out:
# (148, 4)

# %%
list(df.columns)
# Out:
# ['Service', 'Custodian', 'Delivered by', 'Policy area']

# %%
df.head()
# Out:
#                     Service  Custodian  \
# 0           Adapt a vehicle  Not known
# 1             Adopt a child  Not known
# 2      Apply for a passport  Not known
# 3    Be re-setted in the UK  Not known
# 4  Become a British citizen  Not known
#
#                                         Delivered by              Policy area
# 0                                          DVLA DVSA                  driving
# 1  Courts-Tribunals-Service DfE Passport-Office l...  childcare-and-parenting
# 2                                    Passport-Office    visas-and-immigration
# 3                       Home-Office local-government    visas-and-immigration
# 4                                        Home-Office    visas-and-immigration

# %%
df.tail()
# Out:
#                               Service  Custodian  \
# 143            Use accessible parking  Not known
# 144                      Visit the UK  Not known
# 145                         Volunteer  Not known
# 146  What to do when someone has died  Not known
# 147                       Work abroad  Not known
#
#                                         Delivered by  \
# 143                             DfT local-government
# 144            Border-Force DCMS FCO Passport-Office
# 145                Cabinet-Office charity-sector DWP
# 146  DoH HMRC funeralcare-industry local-government
# 147                             FCO HMRC Home-Office
#
#                           Policy area
# 143                           driving
# 144             visas-and-immigration
# 145                       citizenship
# 146  births-deaths-marriages-and-care
# 147             visas-and-immigration

# %%
df.head(20)
# Out:
#                                   Service  Custodian  \
# 0                         Adapt a vehicle  Not known
# 1                           Adopt a child  Not known
# 2                    Apply for a passport  Not known
# 3                  Be re-setted in the UK  Not known
# 4                Become a British citizen  Not known
# 5                    Become a childminder  Not known
# 6                   Become a scrap dealer  Not known
# 7                              Breed dogs  Not known
# 8                   Bring a pet to the UK  Not known
# 9   Bring freight in to and out of the UK  Not known
# 10                            Build a car  Not known
# 11                           Build at sea  Not known
# 12           Buy a business with vehicles  Not known
# 13                            Buy a house  Not known
# 14        Buy a personalised registration  Not known
# 15                         Buy a vehicle   Not known
# 16                               Buy land  Not known
# ...

# %%
df.tail(10)
# Out:
#                               Service  Custodian  \
# 138                   Transport goods  Not known
# 139              Transport passengers  Not known
# 140         Travel to other countries  Not known
# 141            Update driving licence  Not known
# 142                       Use a crane  Not known
# 143            Use accessible parking  Not known
# 144                      Visit the UK  Not known
# 145                         Volunteer  Not known
# 146  What to do when someone has died  Not known
# 147                       Work abroad  Not known
#
#                                         Delivered by  \
# 138                                   DVLA DVSA HMRC
# 139                                        DVLA DVSA
# 140                Border-Force FCO Passport-Office
# 141                                             DVLA
# 142                                 local-government
# 143                             DfT local-government
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Service       148 non-null    object
#  1   Custodian     148 non-null    object
#  2   Delivered by  148 non-null    object
#  3   Policy area   148 non-null    object
# dtypes: object(4)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#                 Service  Custodian Delivered by Policy area
# count               148        148          148         148
# unique              148          6           96          16
# top     Adapt a vehicle  Not known         DVLA     driving
# freq                  1        143           12          44

# %%
s = pd.Series([1,2,3],index=[220,"aki",345])
s
# Out:
# 220    1
# aki    2
# 345    3
# dtype: int64

# %%
d = pd.DataFrame(s,columns=['name'])

# %%
d
# Out:
#      name
# 220     1
# aki     2
# 345     3

# %%
d['new-column'] = 'akii'

# %%
d
# Out:
#      name new-column
# 220     1       akii
# aki     2       akii
# 345     3       akii

# %%
d['new-column-2'] = ['1',2,3]
d
# Out:
#      name new-column new-column-2
# 220     1       akii            1
# aki     2       akii            2
# 345     3       akii            3

# %%
d.columns
# Out:
# Index(['name', 'new-column', 'new-column-2'], dtype='object')

# %%
d.columns = ['hello', 'world', 'new']

# %%
d.reset_index()
# Out:
#   index  hello world new
# 0   220      1  akii   1
# 1   aki      2  akii   2
# 2   345      3  akii   3

# %%
d.reset_index(drop=True)
# Out:
#    hello world new
# 0      1  akii   1
# 1      2  akii   2
# 2      3  akii   3

# %%
d
# Out:
#      hello world new
# 220      1  akii   1
# aki      2  akii   2
# 345      3  akii   3

# %% [markdown]
# # Day 07

# %%
df1 = pd.read_excel("./helperFiles/sample.xls",engine="xlrd")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df1 = pd.read_excel("./helperFiles/sample.xls",engine="xlrd")
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df1 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
df[1].head()
# Out:
#     Rk         Player   Age Team Pos     G    GS     MP     FG    FGA  ...  \
# 0  1.0   LeBron James  30.0  CLE  SF  20.0  20.0  844.0  227.0  544.0  ...
# 1  2.0  Stephen Curry  26.0  GSW  PG  21.0  21.0  826.0  200.0  439.0  ...
# 2  3.0   James Harden  25.0  HOU  SG  17.0  17.0  636.0  129.0  294.0  ...
# 3  4.0  Klay Thompson  24.0  GSW  SG  21.0  21.0  761.0  149.0  334.0  ...
# 4  5.0  Blake Griffin  25.0  LAC  PF  14.0  14.0  557.0  140.0  274.0  ...
#
#      DRB    TRB    AST   STL   BLK   TOV    PF    PTS  Trp-Dbl  Awards
# 0  189.0  226.0  169.0  33.0  21.0  82.0  58.0  601.0      3.0     NaN
# 1   85.0  105.0  134.0  39.0   3.0  82.0  47.0  594.0      0.0     NaN
# 2   85.0   97.0  128.0  28.0   7.0  77.0  49.0  462.0      1.0     NaN
# 3   72.0   81.0   54.0  16.0  19.0  41.0  64.0  391.0      0.0     NaN
# 4  140.0  178.0   86.0  14.0  14.0  45.0  43.0  357.0      3.0     NaN
#
# [5 rows x 32 columns]

# %%
df1[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 32 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       651 non-null    float64
#  1   Player   652 non-null    object
#  2   Age      651 non-null    float64
#  3   Team     651 non-null    object
#  4   Pos      651 non-null    object
#  5   G        651 non-null    float64
#  6   GS       651 non-null    float64
#  7   MP       651 non-null    float64
#  8   FG       651 non-null    float64
#  9   FGA      651 non-null    float64
#  10  FG%      650 non-null    float64
#  11  3P       651 non-null    float64
#  12  3PA      651 non-null    float64
#  13  3P%      571 non-null    float64
#  14  2P       651 non-null    float64
#  15  2PA      651 non-null    float64
#  16  2P%      648 non-null    float64
#  17  eFG%     650 non-null    float64
#  18  FT       651 non-null    float64
#  19  FTA      651 non-null    float64
# ...

# %%
df1[0].describe()
# Out:
#                Rk         Age           G          GS           MP  \
# count  651.000000  651.000000  651.000000  651.000000   651.000000
# mean   250.897081   26.500768   45.960061   21.099846  1041.775730
# std    139.168056    4.110914   25.503151   25.932412   806.253103
# min      1.000000   19.000000    1.000000    0.000000     1.000000
# 25%    131.500000   23.000000   24.000000    0.000000   272.000000
# 50%    252.000000   26.000000   48.000000    9.000000   896.000000
# 75%    374.500000   29.000000   70.000000   35.000000  1674.000000
# max    492.000000   38.000000   83.000000   82.000000  2981.000000
#
#                FG          FGA         FG%          3P         3PA  ...  \
# count  651.000000   651.000000  650.000000  651.000000  651.000000  ...
# mean   160.778802   359.763441    0.427437   33.917051   97.419355  ...
# std    148.971531   322.834979    0.100211   44.168306  118.003315  ...
# min      0.000000     0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
df1[0].dtypes[df1[0].dtypes == 'object'].index
# Out:
# Index(['Player', 'Team', 'Pos', 'Awards'], dtype='object')

# %% [markdown]
# # Day 08

# %%
import pandas as pd

# %%
df = pd.read_csv("./helperFiles/Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked AgeGroup
# 0      0         A/5 21171   7.2500   NaN        S    Adult
# 1      0          PC 17599  71.2833   C85        C    Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Adult
# 3      0            113803  53.1000  C123        S    Adult
# ...

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df[df['Survived'] == 1].count()
# Out:
# PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            290
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Cabin          136
# Embarked       340
# AgeGroup       342
# dtype: int64

# %%
import requests

# %%
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\aksha\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...
